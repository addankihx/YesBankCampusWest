# %%
import pandas as pd

# %%
data = pd.read_excel("dataset.xlsx")

# %%
data=data.rename(index=str, columns={"Data format : cust_id_token|current_address3|current_city|current_state|current_pin_code|permanent_address3|permanent_city|permanent_state|permanent_pin_code": "address"})

# %%
data.head()
# Out:
#                                              address
# 0  1||JAMBI|INDONESIA|36126||CHENNAI|TAMIL NADU|6...
# 1  2|INJAMBAKKAM|CHENNAI|TAMIL NADU|600115||LONDO...
# 2  3|ROODEPOORT|JOHANNESBURG|GAUTENG|2169|MANDIR ...
# 3        4||DUBAI|DUBAI|18582||BARODA|GUJARAT|390007
# 4      5||SIRSA|HARYANA|125055||SIRSA|HARYANA|125055

# %%
data
# Out:
#                                               address
# 0   1||JAMBI|INDONESIA|36126||CHENNAI|TAMIL NADU|6...
# 1   2|INJAMBAKKAM|CHENNAI|TAMIL NADU|600115||LONDO...
# 2   3|ROODEPOORT|JOHANNESBURG|GAUTENG|2169|MANDIR ...
# 3         4||DUBAI|DUBAI|18582||BARODA|GUJARAT|390007
# 4       5||SIRSA|HARYANA|125055||SIRSA|HARYANA|125055
# 5   6|TARDEO CIRCLE PT|MUMBAI|MAHARASHTRA|400034|T...
# 6   7|PRADESH|ITANAGAR|ARUNACHAL PRADESH|791111|PO...
# 7   8||LUCKNOW|UTTAR PRADESH|226003||SAUDI ARABIA|...
# 8   9||NORTH PARRAMATTA|NEW SOUTH WALES|2151||GHAZ...
# 9   10|NEAR CENTURY MALL|FUJAIRAH|FUJAIRA EMIRATES...
# 10  11|NEAR BRIDGE STONE COMPANY|PUNE|MAHARASHTRA|...
# 11  12||AMBERNATH|MAHARASHTRA|421501||AMBERNATH|MA...
# 12  13||GURGAON|HARYANA|122002|NEAR GOVT SCHOOL|DA...
# 13  14|BANDRA E NR COLGATE GROUND|MUMBAI|MAHARASHT...
# 14  15||BEIJING|BEIJING|0|NEAR GCC CLUB MIRA ROAD ...
# 15           16||LUDHIANA|PUNJAB|141003||DUBAI|DUBAI|
# ...

# %%
new = df["address"].str.split("|", n = 10, expand = True)
